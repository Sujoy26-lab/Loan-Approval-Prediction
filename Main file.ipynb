# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
import pickle as pk

# %% [markdown]
# LOADING OF DATASET

# %%
df= pd.read_csv(r"D:\Priject\Loan Eligibility Prediction\loan.csv")
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# CHECKING AND CLEANING OF DATA

# %%
df.head()[:5]
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.tail()[:5]
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %% [raw]
# Cleaning

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df.drop(columns=["Loan_ID"], inplace=True)

# %%
df
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# 5      Male     Yes          2      Graduate           Yes             5417
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes         3+      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
# ...

# %% [markdown]
# DATA PROCESSING

# %%
df["TOTAL ASSESTS"]= df.ApplicantIncome + df.CoapplicantIncome

# %%
df.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status',
#        'TOTAL ASSESTS'],
#       dtype='object')

# %%
df.drop(columns=["ApplicantIncome"], inplace=True)

# %%
df.Education.unique()
# Out:
# array(['Graduate', 'Not Graduate'], dtype=object)

# %%
df["Education"] = df["Education"].replace(['Graduate', 'Not Graduate'],[1,0])
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_23016\2803155425.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Education"] = df["Education"].replace(['Graduate', 'Not Graduate'],[1,0])

# %%
df.Education
# Out:
# 1      1
# 2      1
# 3      0
# 4      1
# 5      1
#       ..
# 609    1
# 610    1
# 611    1
# 612    1
# 613    1
# Name: Education, Length: 480, dtype: int64

# %%
df
# Out:
#      Gender Married Dependents  Education Self_Employed  CoapplicantIncome  \
# 1      Male     Yes          1          1            No             1508.0
# 2      Male     Yes          0          1           Yes                0.0
# 3      Male     Yes          0          0            No             2358.0
# 4      Male      No          0          1            No                0.0
# 5      Male     Yes          2          1           Yes             4196.0
# ..      ...     ...        ...        ...           ...                ...
# 609  Female      No          0          1            No                0.0
# 610    Male     Yes         3+          1            No                0.0
# 611    Male     Yes          1          1            No              240.0
# 612    Male     Yes          2          1            No                0.0
# 613  Female      No          0          1           Yes                0.0
#
# ...

# %%
df.Self_Employed.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df["Self_Employed"]= df["Self_Employed"].replace(['No', 'Yes'],[0,1])
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_23016\302191987.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Self_Employed"]= df["Self_Employed"].replace(['No', 'Yes'],[0,1])

# %%
df.Self_Employed
# Out:
# 1      0
# 2      1
# 3      0
# 4      0
# 5      1
#       ..
# 609    0
# 610    0
# 611    0
# 612    0
# 613    1
# Name: Self_Employed, Length: 480, dtype: int64

# %%
df.Property_Area.unique()
# Out:
# array(['Rural', 'Urban', 'Semiurban'], dtype=object)

# %%
df["Property_Area"] = df["Property_Area"].replace(['Rural', 'Urban', 'Semiurban'],[-1,1,0])
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_23016\3385990516.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Property_Area"] = df["Property_Area"].replace(['Rural', 'Urban', 'Semiurban'],[-1,1,0])

# %%
df.Property_Area
# Out:
# 1     -1
# 2      1
# 3      1
# 4      1
# 5      1
#       ..
# 609   -1
# 610   -1
# 611    1
# 612    1
# 613    0
# Name: Property_Area, Length: 480, dtype: int64

# %%
df.Loan_Status.unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
df["Loan_Status"]= df["Loan_Status"].replace(['N', 'Y'],[0,1])
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_23016\1513371305.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Loan_Status"]= df["Loan_Status"].replace(['N', 'Y'],[0,1])

# %%
df['Dependents'] = df['Dependents'].replace('3+', 3)

# %%
df.Married.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df["Married"]=df["Married"].replace(['Yes', 'No'],[1,0])
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_23016\2148608578.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Married"]=df["Married"].replace(['Yes', 'No'],[1,0])

# %%
df.Gender.unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df["Gender"] = df["Gender"].replace(['Male', 'Female'],[1,0])
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_23016\290288991.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Gender"] = df["Gender"].replace(['Male', 'Female'],[1,0])

# %%
df.Loan_Status
# Out:
# 1      0
# 2      1
# 3      1
# 4      1
# 5      1
#       ..
# 609    1
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Loan_Status, Length: 480, dtype: int64

# %% [markdown]
# DATA TRAINING

# %%
input_data=df.drop(columns=["Loan_Status"])
output_data=df["Loan_Status"]

# %%
input_data
# Out:
#      Gender  Married Dependents  Education  Self_Employed  CoapplicantIncome  \
# 1         1        1          1          1              0             1508.0
# 2         1        1          0          1              1                0.0
# 3         1        1          0          0              0             2358.0
# 4         1        0          0          1              0                0.0
# 5         1        1          2          1              1             4196.0
# ..      ...      ...        ...        ...            ...                ...
# 609       0        0          0          1              0                0.0
# 610       1        1          3          1              0                0.0
# 611       1        1          1          1              0              240.0
# 612       1        1          2          1              0                0.0
# 613       0        0          0          1              1                0.0
#
# ...

# %%
output_data
# Out:
# 1      0
# 2      1
# 3      1
# 4      1
# 5      1
#       ..
# 609    1
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Loan_Status, Length: 480, dtype: int64

# %%
x_train,x_test,y_train,y_test= train_test_split(input_data,output_data , test_size=0.2)

# %%
x_test.shape,x_train.shape,y_test.shape,y_train.shape
# Out:
# ((96, 11), (384, 11), (96,), (384,))

# %%
scaler= StandardScaler()

# %%
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %% [markdown]
# MODEL MAKING

# %%
model = LogisticRegression()

# %%
model.fit(x_train_scaled,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# MODEL ACCURACY

# %%
model.score(x_train_scaled,y_train)
# Out:
# 0.8151041666666666

# %%
pred_data = pd.DataFrame([[f"1", "1" ,"1", "1", "0", "1508.0", "128.0", "360.0", "1.0", "-1", "6091.0"]]
 ,
                          columns=[f"Gender",	"Married",	"Dependents"	,"Education",	"Self_Employed"	,"CoapplicantIncome",	"LoanAmount",	"Loan_Amount_Term"	,"Credit_History",	"Property_Area"	,"TOTAL ASSESTS"])

# %%
model.predict(pred_data)
# Out:
# d:\Softwares\Anaconda\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# array([0], dtype=int64)

# %% [markdown]
# CONCLUDED DATA

# %%
with open("Open DAta.pkl", "wb") as f:
    pk.dump(model, f)

with open("Scaled DAta.pkl", "wb") as f:
    pk.dump(scaler, f)

# %% [markdown]
# -> APP.py
